# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from autophasemap import multi_kmeans_run, compute_euclidean_kmeans, BaseDataSet

# %% [markdown]
# In this notebook, we apply the `autophasemap` algorithm to a synthetic phasemap with parabolic phase region.
# Each region is assigned a Gaussian curve $g(t)$ with either a single, double, or triple peak but can be randomly warped along the function domain $t$.
#
# References:
# - [elastic k-means](https://arxiv.org/pdf/2011.12397.pdf)

# %%
# create synthetic data making use of the BaseDataSet that provides essentials components. 
# This example dataset is generated according to the Section 4 in the elastic k-means paper.
class DataSet(BaseDataSet):
    def __init__(self, C, P, n_domain = 100):
        super().__init__(n_domain=n_domain)
        self.t = np.linspace(0,1, num=self.n_domain)
        self.N = C.shape[0]
        self.P = P
        self.C = C
        self.n_clusters = 3
        
    def g(self, t, p):
        out = np.zeros(self.t.shape)
        for i in range(1,p+1):
            zi = np.random.normal(1, 0.1)
            mean = (2*i-1)/(2*p)
            std = 1/(3*p)
            out += zi*self.phi(t, mean, std)

        return out
    
    def phi(self, t, mu, sigma):
        factor = 1/(2*(sigma**2))
        return np.exp(-factor*(t-mu)**2)
    
    def gamma(self):
        a = np.random.uniform(-3, 3)
        if a==0:
            gam = self.t
        else:
            gam = (np.exp(a*self.t)-1)/(np.exp(a)-1)
        return gam
    
    def generate(self):
        self.F = [self.g(self.gamma(), self.P[i]) for i in range(self.N)]

        return

# %% [markdown]
# We synthetically specify parabolic regions and visualize them on the two dimensional design space

# %%
n_grid = 12
x = np.linspace(0,1, n_grid)
y = np.linspace(0,1, n_grid)
X,Y = np.meshgrid(x,y)
points = np.vstack([X.ravel(), Y.ravel()]).T
phase1 = lambda x : 0.5*(x)**2+0.45
phase2 = lambda x : -0.45*(x)**2+0.55

# plot the dummy phase map
def get_label(c):
    if c[1]-phase1(c[0])>0:
        label = 1
    elif c[1]-phase2(c[0])<0:
        label = 2
    else:
        label = 3
        
    return label

labels = [get_label(p) for p in points]

fig, ax = plt.subplots()
sc = ax.scatter(points[:,0], points[:,1], c=labels)
ax.plot(x, phase1(y))
ax.plot(x, phase2(y))
ax.set_ylim([0,1])
cbar = plt.colorbar(sc)
plt.show()

# %% [markdown]
# Now, we can visualize the dataset that contains three phases...

# %%
n_domain = 200

data = DataSet(points, labels)
data.generate()
fig, axs = plt.subplots(1, 3, figsize=(4*3, 4))
for i in range(data.N):
    axs[data.P[i]-1].plot(data.t, data.F[i], color='grey')
plt.show()

# %%
def plot(data, out):
    fig, axs = plt.subplots(1,4, figsize=(4*4, 4))
    for k, ax in enumerate(axs):
        if k==3:
            ax.scatter(data.C[:,0], data.C[:,1], c=out.delta_n)
            continue
        Mk = np.argwhere(out.delta_n==k).squeeze()
        for i in Mk:
            ax.plot(data.t, out.fik_gam[i,k,:], color='grey')
        
        ax.plot(data.t, out.templates[k], lw=3.0, color='tab:red') 
        ax.axis('off')
    plt.show()

# %% [markdown]
# #### Compute the phasemap using the algorithm presented in this manuscript

# %%
N_CLUSTERS = 3
MAX_ITER = 100
VERBOSE = 3

out_elastic = multi_kmeans_run(2,
                               data, 
                               N_CLUSTERS, 
                               max_iter=MAX_ITER, 
                               verbose=VERBOSE, 
                               smoothen=True)
plot(data, out_elastic)
# Out:
# (0:00:19.478020)	Iteration : 0	Error : 1.1647
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 MAX_ITER = 100
#       3 VERBOSE = 3
# ----> 5 out_elastic = multi_kmeans_run(2,
#       6                                data,
#       7                                N_CLUSTERS,
#       8                                max_iter=MAX_ITER,
#       9                                verbose=VERBOSE,
#      10                                smoothen=True)
#      11 plot(data, out_elastic)
#
# File ~/Documents/codebase/autophasemap/autophasemap/clustering.py:228, in multi_kmeans_run(n_runs, data, n_clusters, max_iter, verbose, smoothen)
#     226 for i in range(n_runs):
#     227     random_sample = np.random.choice(np.arange(data.N), n_clusters)
# --> 228     res = compute_elastic_kmeans(data, random_sample, max_iter, verbose, smoothen)
#     229     if best_error is None or (
#     230             res.error < best_error
#     231             and not _is_same_clustering(res.delta_n, best_labels, n_clusters)
#     232         ):
#     233             best_labels = res.delta_n
#
# File ~/Documents/codebase/autophasemap/autophasemap/clustering.py:153, in compute_elastic_kmeans(data, random_sample, max_iter, verbose, smoothen)
#     150 eta_ray = ray.put(eta)
#     152 results_ids = [compute_cluster_distance.remote(i, DATA_RAY, eta_ray) for i in range(data.N)]
# --> 153 results = ray.get(results_ids)
#     155 d_amplitude, gam_ik, qik_gam, fik_gam = process_step2a(results, data, n_clusters)
#     157 #step 2b
#
# File ~/Documents/codebase/envs/autophasemap/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/Documents/codebase/envs/autophasemap/lib/python3.8/site-packages/ray/worker.py:1825, in get(object_refs, timeout)
#    1819     raise ValueError(
#    1820         "'object_refs' must either be an object ref "
#    1821         "or a list of object refs."
#    1822     )
#    1824 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1825 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    1826 for i, value in enumerate(values):
#    1827     if isinstance(value, RayError):
#
# File ~/Documents/codebase/envs/autophasemap/lib/python3.8/site-packages/ray/worker.py:364, in Worker.get_objects(self, object_refs, timeout)
#     358         raise TypeError(
#     359             f"Attempting to call `get` on the value {object_ref}, "
#     360             "which is not an ray.ObjectRef."
#     361         )
#     363 timeout_ms = int(timeout * 1000) if timeout else -1
# --> 364 data_metadata_pairs = self.core_worker.get_objects(
#     365     object_refs, self.current_task_id, timeout_ms
#     366 )
#     367 debugger_breakpoint = b""
#     368 for (data, metadata) in data_metadata_pairs:
#
# File python/ray/_raylet.pyx:1200, in ray._raylet.CoreWorker.get_objects()
#
# File python/ray/_raylet.pyx:169, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %% [markdown]
# #### Compare it with Euclidean kmeans clustering as a baseline

# %%
N_CLUSTERS = 3
MAX_ITER = 300
VERBOSE = 0

out_euclidean = compute_euclidean_kmeans(data, N_CLUSTERS, 
    max_iter=MAX_ITER, 
    verbose=VERBOSE, 
    smoothen=True
    )
plot(data, out_euclidean)
# Out:
# Error : 266.3125 and took 0:00:00.044866
