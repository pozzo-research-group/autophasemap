# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from autophasemap import multi_kmeans_run, compute_euclidean_kmeans, BaseDataSet

# %% [markdown]
# In this notebook, we apply the `autophasemap` algorithm to a synthetic phasemap with parabolic phase region.
# Each region is assigned a Gaussian curve $g(t)$ with either a single, double, or triple peak but can be randomly warped along the function domain $t$.
#
# References:
# - [elastic k-means](https://arxiv.org/pdf/2011.12397.pdf)

# %%
# create synthetic data making use of the BaseDataSet that provides essentials components. 
# This example dataset is generated according to the Section 4 in the elastic k-means paper.
class DataSet(BaseDataSet):
    def __init__(self, C, P, n_domain = 100):
        super().__init__(n_domain=n_domain)
        self.t = np.linspace(0,1, num=self.n_domain)
        self.N = C.shape[0]
        self.P = P
        self.C = C
        self.n_clusters = 3
        
    def g(self, t, p):
        out = np.zeros(self.t.shape)
        for i in range(1,p+1):
            zi = np.random.normal(1, 0.1)
            mean = (2*i-1)/(2*p)
            std = 1/(3*p)
            out += zi*self.phi(t, mean, std)

        return out
    
    def phi(self, t, mu, sigma):
        factor = 1/(2*(sigma**2))
        return np.exp(-factor*(t-mu)**2)
    
    def gamma(self):
        a = np.random.uniform(-3, 3)
        if a==0:
            gam = self.t
        else:
            gam = (np.exp(a*self.t)-1)/(np.exp(a)-1)
        return gam
    
    def generate(self):
        self.F = [self.g(self.gamma(), self.P[i]) for i in range(self.N)]

        return

# %% [markdown]
# We synthetically specify parabolic regions and visualize them on the two dimensional design space

# %%
n_grid = 12
x = np.linspace(0,1, n_grid)
y = np.linspace(0,1, n_grid)
X,Y = np.meshgrid(x,y)
points = np.vstack([X.ravel(), Y.ravel()]).T
phase1 = lambda x : 0.5*(x)**2+0.45
phase2 = lambda x : -0.45*(x)**2+0.55

# plot the dummy phase map
def get_label(c):
    if c[1]-phase1(c[0])>0:
        label = 1
    elif c[1]-phase2(c[0])<0:
        label = 2
    else:
        label = 3
        
    return label

labels = [get_label(p) for p in points]

fig, ax = plt.subplots()
sc = ax.scatter(points[:,0], points[:,1], c=labels)
ax.plot(x, phase1(y))
ax.plot(x, phase2(y))
ax.set_ylim([0,1])
cbar = plt.colorbar(sc)
plt.show()

# %% [markdown]
# Now, we can visualize the dataset that contains three phases...

# %%
n_domain = 200

data = DataSet(points, labels)
data.generate()
fig, axs = plt.subplots(1, 3, figsize=(4*3, 4))
for i in range(data.N):
    axs[data.P[i]-1].plot(data.t, data.F[i], color='grey')
plt.show()

# %%
def plot(data, out):
    fig, axs = plt.subplots(1,4, figsize=(4*4, 4))
    for k, ax in enumerate(axs):
        if k==3:
            ax.scatter(data.C[:,0], data.C[:,1], c=out.delta_n)
            continue
        Mk = np.argwhere(out.delta_n==k).squeeze()
        for i in Mk:
            ax.plot(data.t, out.fik_gam[i,k,:], color='grey')
        
        ax.plot(data.t, out.templates[k], lw=3.0, color='tab:red') 
        ax.axis('off')
    plt.show()

# %% [markdown]
# #### Compute the phasemap using the algorithm presented in this manuscript

# %%
N_CLUSTERS = 3
MAX_ITER = 50
VERBOSE = 3

out_elastic, bic = multi_kmeans_run(2,
                               data, 
                               N_CLUSTERS, 
                               max_iter=MAX_ITER, 
                               verbose=VERBOSE, 
                               smoothen=True,
                               threshold = 1e-2,
                               grid_dim = 8
                               )
plot(data, out_elastic)
# Out:
# (0:00:03.072134)	Iteration : 0	Error : 1.0543
# (0:00:10.190833)	Iteration : 5	Error : 0.0151
# Error threshold reached...
# Total iterations 6	Error : 0.0074 and took 0:00:11.597597
# Random init of 1/2 current error : 0.0074 and BIC : -614.3499
# Error threshold reached...

# %% [markdown]
# #### Compare it with Euclidean kmeans clustering as a baseline

# %%
N_CLUSTERS = 3
MAX_ITER = 300
VERBOSE = 0

out_euclidean = compute_euclidean_kmeans(data, N_CLUSTERS, 
    max_iter=MAX_ITER, 
    verbose=VERBOSE, 
    smoothen=True
    )
plot(data, out_euclidean)
# Out:
# Error : 260.2005 and took 0:00:00.065183

# %% [markdown]
# ### Finding number of clusters using BIC

# %%
SWEEP_N_CLUSTERS = np.arange(1, 6)
MAX_ITER = 50
VERBOSE = 3
N_INIT_RUNS = 5
out_list, bic_list = [],[]
for i in SWEEP_N_CLUSTERS:
    out_elastic, bic = multi_kmeans_run(1 if i==1 else N_INIT_RUNS,
                                        data, 
                                        i, 
                                        max_iter=MAX_ITER, 
                                        verbose=VERBOSE, 
                                        smoothen=True,
                                        threshold = 1e-2,
                                        grid_dim = 8
                                        )
    out_list.append(out_elastic)
    bic_list.append(bic)
# Out:
# (0:00:00.935831)	Iteration : 0	Error : 0.7788
# (0:00:05.508597)	Iteration : 5	Error : 0.1268
# (0:00:10.029557)	Iteration : 10	Error : 0.2857
# (0:00:14.532288)	Iteration : 15	Error : 0.0312
# (0:00:19.027235)	Iteration : 20	Error : 0.0380
# (0:00:23.511928)	Iteration : 25	Error : 0.2212
# (0:00:29.007841)	Iteration : 30	Error : 0.3929
# (0:00:33.996741)	Iteration : 35	Error : 0.3918
# (0:00:38.728530)	Iteration : 40	Error : 0.3911
# (0:00:43.513295)	Iteration : 45	Error : 0.3944
# Total iterations 49	Error : 0.3927 and took 0:00:47.453756
# Random init of 1/1 current error : 0.3927 and BIC : 2729.8369
# (0:00:01.292002)	Iteration : 0	Error : 0.6799
# (0:00:07.529189)	Iteration : 5	Error : 0.0555
# (0:00:13.688462)	Iteration : 10	Error : 0.0150
# Error threshold reached...
# Total iterations 11	Error : 0.0064 and took 0:00:14.870688
# Random init of 1/5 current error : 0.0064 and BIC : 1063.9894
# Error threshold reached...
# (0:00:01.490764)	Iteration : 0	Error : 0.7344
# (0:00:09.004023)	Iteration : 5	Error : 0.0217
# (0:00:16.435330)	Iteration : 10	Error : 0.0374
# (0:00:23.567543)	Iteration : 15	Error : 0.0532
# (0:00:30.919376)	Iteration : 20	Error : 0.0254
# (0:00:38.351858)	Iteration : 25	Error : 0.0478
# (0:00:45.548217)	Iteration : 30	Error : 0.0590
# (0:00:52.641814)	Iteration : 35	Error : 0.0196
# (0:00:59.792636)	Iteration : 40	Error : 0.0715
# (0:01:06.920092)	Iteration : 45	Error : 0.0260
# Total iterations 49	Error : 0.0767 and took 0:01:12.733851
# Random init of 1/5 current error : 0.0767 and BIC : -595.3756
# (0:00:01.485969)	Iteration : 0	Error : 1.1734
# (0:00:08.668198)	Iteration : 5	Error : 0.0114
# Error threshold reached...
# Total iterations 8	Error : 0.0097 and took 0:00:13.118846
# Random init of 2/5 current error : 0.0767 and BIC : -595.3756
# (0:00:01.528932)	Iteration : 0	Error : 0.7589
# (0:00:09.470702)	Iteration : 5	Error : 0.0180
# (0:00:16.611318)	Iteration : 10	Error : 0.0398
# (0:00:23.675887)	Iteration : 15	Error : 0.0433
# (0:00:31.838971)	Iteration : 20	Error : 0.0151
# (0:00:39.515418)	Iteration : 25	Error : 0.0170
# (0:00:47.197874)	Iteration : 30	Error : 0.0115
# (0:00:54.728620)	Iteration : 35	Error : 0.0434
# (0:01:02.106550)	Iteration : 40	Error : 0.0140
# (0:01:09.643103)	Iteration : 45	Error : 0.0160
# Total iterations 49	Error : 0.0140 and took 0:01:15.535148
# Random init of 3/5 current error : 0.0767 and BIC : -595.3756
# (0:00:01.581100)	Iteration : 0	Error : 0.6159
# (0:00:08.999670)	Iteration : 5	Error : 0.0183
# (0:00:16.655142)	Iteration : 10	Error : 0.0149
# (0:00:24.111807)	Iteration : 15	Error : 0.0450
# (0:00:31.322289)	Iteration : 20	Error : 0.0154
# (0:00:38.631010)	Iteration : 25	Error : 0.0388
# (0:00:45.954031)	Iteration : 30	Error : 0.0250
# (0:00:53.230760)	Iteration : 35	Error : 0.0235
# (0:01:00.568746)	Iteration : 40	Error : 0.0177
# (0:01:08.209687)	Iteration : 45	Error : 0.0224
# Total iterations 49	Error : 0.0214 and took 0:01:14.220600
# Random init of 4/5 current error : 0.0767 and BIC : -595.3756
# (0:00:01.449620)	Iteration : 0	Error : 0.9914
# (0:00:08.848981)	Iteration : 5	Error : 0.0267
# Error threshold reached...
# Total iterations 10	Error : 0.0088 and took 0:00:16.043120
# Random init of 5/5 current error : 0.0767 and BIC : -595.3756
# (0:00:01.736651)	Iteration : 0	Error : 0.9161
# (0:00:10.519693)	Iteration : 5	Error : 0.0588
# (0:00:19.467575)	Iteration : 10	Error : 0.0564
# (0:00:29.166817)	Iteration : 15	Error : 0.1412
# (0:00:38.159198)	Iteration : 20	Error : 0.0940
# (0:00:48.405370)	Iteration : 25	Error : 0.0106
# Error threshold reached...
# Total iterations 30	Error : 0.0084 and took 0:00:57.374263
# Random init of 1/5 current error : 0.0084 and BIC : -268.4685
# Error threshold reached...
# (0:00:02.085253)	Iteration : 0	Error : 0.9276
# (0:00:12.712102)	Iteration : 5	Error : 0.3365
# (0:00:23.290622)	Iteration : 10	Error : 0.0216
# (0:00:34.032335)	Iteration : 15	Error : 0.1945
# (0:00:44.133887)	Iteration : 20	Error : 0.0226
# (0:00:54.102192)	Iteration : 25	Error : 0.0184
# (0:01:04.075259)	Iteration : 30	Error : 0.3032
# (0:01:14.111885)	Iteration : 35	Error : 0.3089
# (0:01:24.264401)	Iteration : 40	Error : 0.0761
# (0:01:34.583085)	Iteration : 45	Error : 0.3054
# Total iterations 49	Error : 0.3116 and took 0:01:42.771083
# Random init of 1/5 current error : 0.3116 and BIC : 264.3824
# (0:00:02.030915)	Iteration : 0	Error : 1.1313
# (0:00:12.413666)	Iteration : 5	Error : 0.0995
# (0:00:22.623717)	Iteration : 10	Error : 0.0956
# (0:00:32.685100)	Iteration : 15	Error : 0.2897
# (0:00:42.583235)	Iteration : 20	Error : 0.1652
# (0:00:52.648168)	Iteration : 25	Error : 0.3086
# (0:01:02.932147)	Iteration : 30	Error : 0.0479
# (0:01:12.845220)	Iteration : 35	Error : 0.0739
# (0:01:22.930996)	Iteration : 40	Error : 0.0857
# (0:01:33.050332)	Iteration : 45	Error : 0.1780
# Total iterations 49	Error : 0.1778 and took 0:01:41.612926
# Random init of 2/5 current error : 0.1778 and BIC : 351.7391
# (0:00:02.219240)	Iteration : 0	Error : 0.8773
# (0:00:12.976162)	Iteration : 5	Error : 0.2878
# (0:00:23.455839)	Iteration : 10	Error : 0.2433
# (0:00:34.121527)	Iteration : 15	Error : 0.2290
# (0:00:43.986191)	Iteration : 20	Error : 0.0209
# (0:00:53.781396)	Iteration : 25	Error : 0.1377
# (0:01:03.770154)	Iteration : 30	Error : 0.1242
# (0:01:13.807459)	Iteration : 35	Error : 0.0475
# (0:01:23.680306)	Iteration : 40	Error : 0.1128
# (0:01:33.753490)	Iteration : 45	Error : 0.1532
# Total iterations 49	Error : 0.0538 and took 0:01:46.034277
# Random init of 3/5 current error : 0.0538 and BIC : 356.0207
# (0:00:02.154729)	Iteration : 0	Error : 0.6290
# (0:00:12.397587)	Iteration : 5	Error : 0.1514
# (0:00:22.876786)	Iteration : 10	Error : 0.0575
# (0:00:33.429135)	Iteration : 15	Error : 0.0930
# (0:00:44.402550)	Iteration : 20	Error : 0.0979
# (0:00:54.716423)	Iteration : 25	Error : 0.0745
# (0:01:05.573374)	Iteration : 30	Error : 0.1738
# (0:01:16.337282)	Iteration : 35	Error : 0.3516
# (0:01:26.796598)	Iteration : 40	Error : 0.2433
# (0:01:36.734559)	Iteration : 45	Error : 0.2549
# Total iterations 49	Error : 0.1821 and took 0:01:45.605103
# Random init of 4/5 current error : 0.0538 and BIC : 356.0207
# (0:00:02.159079)	Iteration : 0	Error : 0.7947
# (0:00:12.266566)	Iteration : 5	Error : 0.3920
# (0:00:22.150634)	Iteration : 10	Error : 0.0373
# (0:00:32.480633)	Iteration : 15	Error : 0.1728
# (0:00:42.779088)	Iteration : 20	Error : 0.3710
# (0:00:53.124183)	Iteration : 25	Error : 0.1646
# (0:01:03.778821)	Iteration : 30	Error : 0.1351
# (0:01:14.247492)	Iteration : 35	Error : 0.2977
# (0:01:24.494265)	Iteration : 40	Error : 0.1210
# (0:01:34.940557)	Iteration : 45	Error : 0.0717
# Total iterations 49	Error : 0.0681 and took 0:01:42.988345
# Random init of 5/5 current error : 0.0538 and BIC : 356.0207

# %%
bic_mean_std = np.zeros((len(SWEEP_N_CLUSTERS), 2))
for i, bic in enumerate(bic_list):
    bic_mean_std[i, :] = [np.asarray(bic).mean(), np.asarray(bic).std()]
fig, ax = plt.subplots()
ax.errorbar(SWEEP_N_CLUSTERS, bic_mean_std[:,0], bic_mean_std[:,1], fmt='-o')
ax.set_xticks(ticks=SWEEP_N_CLUSTERS)
plt.show()
